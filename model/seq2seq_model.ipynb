# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from tqdm import tqdm

import numpy as np
import matplotlib.pyplot as plt
import pickle
import os
# !pip install konlpy
from konlpy.tag import Okt
import re
import pickle

from tensorflow import keras
from keras import models
from keras import layers
from keras import optimizers, losses, metrics
from keras import preprocessing
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

import warnings
# WARNING 무시
warnings.filterwarnings('ignore')

# %% [markdown]
# #데이터 불러오기

# %%
corpus = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/ssac/nlp/data/음식점_train.csv')
corpus
# Out:
#            IDX 발화자                               발화문 카테고리   QA번호 QA여부 감성  \
# 0            1   c             참치타다끼샐러드는 취소했었는데, 맞죠?  음식점  32365    q  m
# 1            2   s           네, 참치타다끼샐러드는 취소된 상태입니다.  음식점  32365    a  m
# 2            3   c  주문한 메뉴 취소할 때 주문서만 있으면 된다는 말씀이세요?  음식점  15016    q  m
# 3            4   s             네, 주문서만 있으면 취소 가능합니다.  음식점  15016    a  m
# 4            5   c             고객서비스가 엉망이군요. 그냥 갑니다.  음식점  62984    q  n
# ...        ...  ..                               ...  ...    ...  ... ..
# 290382  290383   s        성북동까지 지금 시간에는 40분 이상 걸립니다.  음식점  50614    a  m
# 290383  290384   c         짜장면 지금 주문하면 바로 배달 올 수 있죠?  음식점  18579    q  m
# 290384  290385   s            네, 지금 주문하시면 바로 배달 갑니다.  음식점  18579    a  m
# 290385  290386   c    롯데유치원에 피자 20판 보내야하는데 5시까지 될까요?  음식점  59570    q  m
# 290386  290387   s       네, 피자 20판 5시까지 보내드릴 수 있습니다.  음식점  59570    a  m
#
#              인텐트   가격   수량   크기     장소   조직   사람   시간   날짜       상품명   상담번호  \
# 0       주문_취소_확인  NaN  NaN  NaN    NaN  NaN  NaN  NaN  NaN  참치타다끼샐러드  32365
# 1       주문_취소_확인  NaN  NaN  NaN    NaN  NaN  NaN  NaN  NaN  참치타다끼샐러드  32365
# 2       주문_취소_확인  NaN  NaN  NaN    NaN  NaN  NaN  NaN  NaN       NaN  15016
# 3       주문_취소_확인  NaN  NaN  NaN    NaN  NaN  NaN  NaN  NaN       NaN  15016
# 4       주문_취소_확인  NaN  NaN  NaN    NaN  NaN  NaN  NaN  NaN       NaN  62984
# ...          ...  ...  ...  ...    ...  ...  ...  ...  ...       ...    ...
# 290382  배송_날짜_요청  NaN  NaN  NaN    성북동  NaN  NaN  NaN  NaN       NaN  50614
# 290383  배송_날짜_요청  NaN  NaN  NaN    NaN  NaN  NaN  NaN  NaN       짜장면  18579
# 290384  배송_날짜_요청  NaN  NaN  NaN    NaN  NaN  NaN  NaN  NaN       NaN  18579
# 290385  배송_날짜_요청  NaN  NaN  NaN  롯데유치원  NaN  NaN   5시  NaN        피자  59570
# 290386  배송_날짜_요청  NaN  NaN  NaN    NaN  NaN  NaN   5시  NaN        피자  59570
#
#         상담내순번
# 0           1
# 1           2
# 2           1
# 3           2
# 4           1
# ...       ...
# 290382      2
# 290383      1
# 290384      2
# 290385      1
# 290386      2
#
# [290387 rows x 19 columns]

# %%
# 질문과 대답형식의 데이터로 변경
Q = []
A = []
flag = 0
for i in tqdm(range(len(corpus))):
  if flag > i :
    pass
  else :
    if corpus.iloc[i]['QA여부'] == 'q':
      list_q = []
      list_q.append(corpus.iloc[i]['발화문'])
      for j in range(i+1, len(corpus)):
        if corpus.iloc[j]['QA여부'] == 'a':
          flag = j
        if flag == j:
          break
        else : 
          list_q.append(corpus.iloc[j]['발화문'])
      Q.append(' '.join(list_q))
    else :
      list_a = []
      list_a.append(corpus.iloc[i]['발화문'])
      for j in range(i+1, i+50):
        try : 
          if corpus.iloc[j]['QA여부'] == 'q':
            flag = j

          if flag == j:
            break
          else : 
            list_a.append(corpus.iloc[j]['발화문'])
        except :
          pass
      A.append(' '.join(list_a))
# Out:
# 100%|██████████| 290387/290387 [01:31<00:00, 3190.49it/s]

# %%
corpus = pd.DataFrame({'Q':Q, 'A':A})
corpus
# Out:
#                                                 Q  \
# 0                           참치타다끼샐러드는 취소했었는데, 맞죠?
# 1                주문한 메뉴 취소할 때 주문서만 있으면 된다는 말씀이세요?
# 2                           고객서비스가 엉망이군요. 그냥 갑니다.
# 3                 방금 전에 홍합탕 주문한 거 지금 취소 가능한 거 맞죠?
# 4       매운무뼈닭발 롯데주유소로 주문한 거 아직 안받았는데, 취소해도 되는 거죠?
# ...                                           ...
# 119372      짜장면 12:30까지 배달되야 먹는데 그 시간까지 오실 수 있나요?
# 119373             후라이드 5마리 시킨 곳인데 배달 출발한 거 확실해요?
# 119374             성북동까지 치킨 배달시키면 얼마나 걸리는지 알려주세요.
# 119375                  짜장면 지금 주문하면 바로 배달 올 수 있죠?
# 119376             롯데유치원에 피자 20판 보내야하는데 5시까지 될까요?
#
#                                        A
# 0                네, 참치타다끼샐러드는 취소된 상태입니다.
# 1                  네, 주문서만 있으면 취소 가능합니다.
# 2                원하시는 서비스를 제공하지못해 죄송합니다.
# 3       네, 주문하신 홍합탕은 아직 조리 전이라 취소 가능합니다.
# 4        아니요, 이미 접수 후 조리 시작하여 취소는 어렵습니다.
# ...                                  ...
# 119372            네, 말씀하신 시간까지 배달해 드릴게요.
# 119373     네, 배달 출발한 건지 알아 보고 연락 드리겠습니다.
# 119374        성북동까지 지금 시간에는 40분 이상 걸립니다.
# 119375            네, 지금 주문하시면 바로 배달 갑니다.
# 119376       네, 피자 20판 5시까지 보내드릴 수 있습니다.
#
# [119377 rows x 2 columns]

# %%
#대답이 '네'인 데이터는 제거
corpus = corpus[corpus['A'] != '네'][corpus['A'] != '네.']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # 데이터 전처리

# %%
#데이터를 리스트로
df = corpus['Q']
get_all_texts = df.values.tolist()
df = corpus['A']
get_all_pairs = df.values.tolist()

# %%
texts = []
pairs = []

for text, pair in zip(get_all_texts, get_all_pairs):
    texts.append(text)
    pairs.append(pair)
list(zip(texts, pairs))[:5]
# Out:
# [('참치타다끼샐러드는 취소했었는데, 맞죠?', '네, 참치타다끼샐러드는 취소된 상태입니다.'),
#  ('주문한 메뉴 취소할 때 주문서만 있으면 된다는 말씀이세요?', '네, 주문서만 있으면 취소 가능합니다.'),
#  ('고객서비스가 엉망이군요. 그냥 갑니다.', '원하시는 서비스를 제공하지못해 죄송합니다.'),
#  ('방금 전에 홍합탕 주문한 거 지금 취소 가능한 거 맞죠?', '네, 주문하신 홍합탕은 아직 조리 전이라 취소 가능합니다.'),
#  ('매운무뼈닭발 롯데주유소로 주문한 거 아직 안받았는데, 취소해도 되는 거죠?',
#   '아니요, 이미 접수 후 조리 시작하여 취소는 어렵습니다.')]

# %%
def clean_sentence(sentence):
    sentence = re.sub(r'[^0-9ㄱ-ㅎㅏ-ㅣ가-힣 ]',r'', sentence)
    return sentence

# %%
okt = Okt()
def process_morph(sentence):
    return ' '.join(okt.morphs(sentence))
# Out:
# Requirement already satisfied: konlpy in /usr/local/lib/python3.7/dist-packages (0.6.0)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.21.5)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.3.0)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (3.10.0.2)

# %%
def clean_and_morph(sentence, is_question=True):
    # 한글 문장 전처리
    sentence = clean_sentence(sentence)
    # 형태소 변환
    sentence = process_morph(sentence)
    # Question 인 경우, Answer인 경우를 분기하여 처리
    if is_question:
        return sentence
    else:
        # <SOS> 토큰은 decoder input에 <EOS> 토큰은 decoder output에 추가
        return ('<SOS> ' + sentence, sentence + ' <EOS>')

# %%
def preprocess(texts, pairs):
    questions = []
    answer_in = []
    answer_out = []

    # 질의에 대한 전처리
    for text in texts:
        question = clean_and_morph(text, is_question=True)
        questions.append(question)

    # 답변에 대한 전처리
    for pair in pairs:
        in_, out_ = clean_and_morph(pair, is_question=False)
        answer_in.append(in_)
        answer_out.append(out_)
    
    return questions, answer_in, answer_out

# %%
#데이터 사이즈 조정
texts = texts[:5000]
pairs = pairs[:5000]

# %%
#데이터 전처리 적용
questions, answer_in, answer_out = preprocess(texts, pairs)

# %%
#단어사전 생성
all_sentences = questions + answer_in + answer_out
a = (' '.join(questions) + ' '.join(answer_in) + ' '.join(answer_out)).split()
len(set(a))
# Out:
# 5164

# %%
#tokenizer 정의
tokenizer = Tokenizer(filters='', lower=False, oov_token='<OOV>')

# %%
tokenizer.fit_on_texts(all_sentences)
for word, idx in tokenizer.word_index.items():
    print(f'{word}\t\t => \t{idx}')
    if idx > 10:
        break
# Out:
# <OOV>		 => 	1
# <SOS>		 => 	2
# <EOS>		 => 	3
# 네		 => 	4
# 배달		 => 	5
# 이		 => 	6
# 비		 => 	7
# 가		 => 	8
# 요		 => 	9
# 에		 => 	10
# 는		 => 	11

# %%
EMBEDDING_DIM = 100      # 임베딩 벡터 차원
LSTM_HIDDEN_DIM = 128    # LSTM 히든레이어 차원
MAX_LENGTH = 30
TRUNCATING = 'post'      #문장이 30을 넘어갈 경우 뒤에서 자르기
PADDING = 'post'         #뒤에서부터 0으로 패딩
VOCAB_SIZE = len(tokenizer.word_index) + 1  # 나중에 <PAD> 위해 +1

# %%
#시퀀스 변환
question_sequence = tokenizer.texts_to_sequences(questions)
answer_in_sequence = tokenizer.texts_to_sequences(answer_in)
answer_out_sequence = tokenizer.texts_to_sequences(answer_out)

# %%
#패딩
question_padded = pad_sequences(question_sequence, maxlen=MAX_LENGTH, truncating=TRUNCATING, padding=PADDING)
answer_in_padded = pad_sequences(answer_in_sequence, maxlen=MAX_LENGTH, truncating=TRUNCATING, padding=PADDING)
answer_out_padded = pad_sequences(answer_out_sequence, maxlen=MAX_LENGTH, truncating=TRUNCATING, padding=PADDING)
  
question_padded.shape
# Out:
# (5000, 30)

# %%
def convert_to_one_hot(padded):
    # 원핫인코딩 초기화
    one_hot_vector = np.zeros((len(answer_out_padded), MAX_LENGTH, VOCAB_SIZE))
    # 학습시 입력은 인덱스이지만, 출력은 원핫인코딩 형식
    for i, sequence in enumerate(answer_out_padded):
        for j, index in enumerate(sequence):
            one_hot_vector[i, j, index] = 1

    return one_hot_vector

# %%
answer_in_one_hot = convert_to_one_hot(answer_in_padded)
answer_out_one_hot = convert_to_one_hot(answer_out_padded)
answer_in_one_hot[0].shape, answer_in_one_hot[0].shape
# Out:
# ((30, 5164), (30, 5164))

# %%
def convert_index_to_text(indexs, end_token): 
    
    sentence = ''
  
    for index in indexs:
        if index == end_token:
            break;
        # 사전에 존재하는 단어의 경우 단어 추가
        if index > 0 and tokenizer.index_word[index] is not None:
            sentence += tokenizer.index_word[index]
        else:
        # 사전에 없는 인덱스면 빈 문자열 추가
            sentence += ''
       
        sentence += ' '
    return sentence

# %%
def make_prediction(model, question_inputs):
    results = model(inputs=question_inputs, training=False)
    # 변환된 인덱스를 문장으로 변환
    results = np.asarray(results).reshape(-1)
    return results

# %% [markdown]
# # 모델링

# %%
#--------------------------------------------
# 훈련 모델 인코더 정의
#--------------------------------------------

# 입력 문장의 인덱스 시퀀스를 입력으로 받음
encoder_inputs = layers.Input(shape=(None,))

# 임베딩 레이어
encoder_outputs = layers.Embedding(VOCAB_SIZE, EMBEDDING_DIM)(encoder_inputs)

# return_state가 True면 상태값 리턴
# LSTM은 state_h(hidden state)와 state_c(cell state) 2개의 상태 존재
encoder_outputs, state_h, state_c LSTM_HIDDEN_DIM,
                                                dropout=0.1,
                                                recurrent_dropout=0.5,
                                                return_state=True)(encoder_outputs)

# 히든 상태와 셀 상태를 하나로 묶음
encoder_states = [state_h, state_c]



#--------------------------------------------
# 훈련 모델 디코더 정의
#--------------------------------------------

# 목표 문장의 인덱스 시퀀스를 입력으로 받음
decoder_inputs = layers.Input(shape=(None,))

# 임베딩 레이어
decoder_embedding = layers.Embedding(VOCAB_SIZE, EMBEDDING_DIM)
decoder_outputs = decoder_embedding(decoder_inputs)


# 인코더와 달리 return_sequences를 True로 설정하여 모든 타임 스텝 출력값 리턴
# 모든 타임 스텝의 출력값들을 다음 레이어의 Dense()로 처리하기 위함
decoder_lstm = layers.LSTM(LSTM_HIDDEN_DIM,
                           dropout=0.1,
                           recurrent_dropout=0.5,
                           return_state=True,
                           return_sequences=True)

# initial_state를 인코더의 상태로 초기화
decoder_outputs, _, _ = decoder_lstm(decoder_outputs,
                                     initial_state=encoder_states)

# 단어의 개수만큼 노드의 개수를 설정하여 원핫 형식으로 각 단어 인덱스를 출력
decoder_dense = layers.Dense(VOCAB_SIZE, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)



#--------------------------------------------
# 훈련 모델 정의
#--------------------------------------------

# 입력과 출력으로 함수형 API 모델 생성
model = models.Model([encoder_inputs, decoder_inputs], decoder_outputs)

# 학습 방법 설정
model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['acc'])
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
#--------------------------------------------
#  예측 모델 인코더 정의
#--------------------------------------------

# 훈련 모델의 인코더 상태를 사용하여 예측 모델 인코더 설정
encoder_model = models.Model(encoder_inputs, encoder_states)



#--------------------------------------------
# 예측 모델 디코더 정의
#--------------------------------------------

# 예측시에는 훈련시와 달리 타임 스텝을 한 단계씩 수행
# 매번 이전 디코더 상태를 입력으로 받아서 새로 설정
decoder_state_input_h = layers.Input(shape=(LSTM_HIDDEN_DIM,))
decoder_state_input_c = layers.Input(shape=(LSTM_HIDDEN_DIM,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]    

# 임베딩 레이어
decoder_outputs = decoder_embedding(decoder_inputs)

# LSTM 레이어
decoder_outputs, state_h, state_c = decoder_lstm(decoder_outputs,
                                                 initial_state=decoder_states_inputs)

# 히든 상태와 셀 상태를 하나로 묶음
decoder_states = [state_h, state_c]

# Dense 레이어를 통해 원핫 형식으로 각 단어 인덱스를 출력
decoder_outputs = decoder_dense(decoder_outputs)

# 예측 모델 디코더 설정
decoder_model = models.Model([decoder_inputs] + decoder_states_inputs,
                      [decoder_outputs] + decoder_states)

# %%
# 에폭 반복
for epoch in range(15):
    print(f'processing epoch: {epoch * 10 + 1}...')

    # 훈련 시작
    history = model.fit([question_padded, answer_in_padded],
                        answer_out_one_hot,
                        epochs=10,
                        batch_size=64)
    # 랜덤한 샘플 번호 추출
    samples = np.random.randint(5000, size=3)

    # 예측 성능 테스트
    for idx in samples:
        # 문장 예측
        input_encoder = question_padded[idx].reshape(1, question_padded[idx].shape[0])
        input_decoder = answer_in_padded[idx].reshape(1, answer_in_padded[idx].shape[0])
        results = model.predict([input_encoder, input_decoder])
        indexs = np.argmax(results[0], 1) 
    
        # 변환된 인덱스를 문장으로 변환
        results = convert_index_to_text(indexs, tokenizer.word_index['<EOS>'])
        
        print(f'Q: {questions[idx]}')
        print(f'A: {results}\n')
        print()
# Out:
# processing epoch: 1...
# Epoch 1/10
# 79/79 [==============================] - 25s 203ms/step - loss: 2.4160 - acc: 0.7656
# Epoch 2/10
# 79/79 [==============================] - 17s 211ms/step - loss: 1.3299 - acc: 0.8041
# Epoch 3/10
# 79/79 [==============================] - 16s 203ms/step - loss: 1.2317 - acc: 0.8183
# Epoch 4/10
# 79/79 [==============================] - 16s 203ms/step - loss: 1.1932 - acc: 0.8217
# Epoch 5/10
# 79/79 [==============================] - 16s 203ms/step - loss: 1.1679 - acc: 0.8230
# Epoch 6/10
# 79/79 [==============================] - 16s 202ms/step - loss: 1.1349 - acc: 0.8267
# Epoch 7/10
# 79/79 [==============================] - 16s 202ms/step - loss: 1.1019 - acc: 0.8302
# Epoch 8/10
# 79/79 [==============================] - 16s 203ms/step - loss: 1.0728 - acc: 0.8325
# Epoch 9/10
# 79/79 [==============================] - 16s 202ms/step - loss: 1.0468 - acc: 0.8347
# Epoch 10/10
# 79/79 [==============================] - 16s 204ms/step - loss: 1.0242 - acc: 0.8366
# Q: 나물 반찬 3 종 세트 에 들어가는 반찬 세 가지 다 궁금해요
# A: 네 있습니다 들어갑니다 이 들어갑니다 들어갑니다 들어갑니다 가 이 들어갑니다
#
#
# Q: 반찬 정기 배송 시키면 배송비 공짜 인가요
# A: 네 포장 됩니다 주세요 배달 됩니다 포함
#
#
# Q: 오곡 빠삭 닭강정 배달 하면 배달 비 얼마 에요
# A: 네 이요
#
#
# processing epoch: 11...
# Epoch 1/10
# 79/79 [==============================] - 17s 209ms/step - loss: 1.0032 - acc: 0.8381
# Epoch 2/10
# 79/79 [==============================] - 17s 210ms/step - loss: 0.9829 - acc: 0.8396
# Epoch 3/10
# 79/79 [==============================] - 16s 205ms/step - loss: 0.9637 - acc: 0.8413
# Epoch 4/10
# 79/79 [==============================] - 16s 207ms/step - loss: 0.9456 - acc: 0.8436
# Epoch 5/10
# 79/79 [==============================] - 18s 231ms/step - loss: 0.9256 - acc: 0.8455
# Epoch 6/10
# 79/79 [==============================] - 17s 216ms/step - loss: 0.9085 - acc: 0.8478
# Epoch 7/10
# 79/79 [==============================] - 17s 209ms/step - loss: 0.8910 - acc: 0.8497
# Epoch 8/10
# 79/79 [==============================] - 16s 205ms/step - loss: 0.8736 - acc: 0.8520
# Epoch 9/10
# 79/79 [==============================] - 16s 204ms/step - loss: 0.8576 - acc: 0.8538
# Epoch 10/10
# 79/79 [==============================] - 16s 205ms/step - loss: 0.8428 - acc: 0.8558
# Q: 아이스크림 한 스쿱 에는 얼마 인가요
# A: 9시 개요 입니다 요 이
#
#
# Q: 오리진 패밀리 박스 세트 는 구성 이 어떻게 되나요
# A: 네 국수 개 샐러드 랑 랑 개 가
#
#
# Q: 치킨 배달 비 2000원 맞아요
# A: 네 배달 비는 무료 추가 추가
#
#
# processing epoch: 21...
# Epoch 1/10
# 79/79 [==============================] - 16s 205ms/step - loss: 0.8272 - acc: 0.8576
# Epoch 2/10
# 79/79 [==============================] - 16s 205ms/step - loss: 0.8128 - acc: 0.8590
# Epoch 3/10
# 79/79 [==============================] - 16s 207ms/step - loss: 0.7987 - acc: 0.8605
# Epoch 4/10
# 79/79 [==============================] - 16s 206ms/step - loss: 0.7848 - acc: 0.8622
# Epoch 5/10
# 79/79 [==============================] - 16s 205ms/step - loss: 0.7717 - acc: 0.8642
# Epoch 6/10
# 79/79 [==============================] - 16s 209ms/step - loss: 0.7603 - acc: 0.8652
# Epoch 7/10
# 79/79 [==============================] - 16s 205ms/step - loss: 0.7470 - acc: 0.8672
# Epoch 8/10
# 79/79 [==============================] - 16s 206ms/step - loss: 0.7346 - acc: 0.8682
# Epoch 9/10
# 79/79 [==============================] - 16s 203ms/step - loss: 0.7235 - acc: 0.8699
# Epoch 10/10
# 79/79 [==============================] - 16s 204ms/step - loss: 0.7122 - acc: 0.8716
# Q: 순 살 소금 구 이 치킨 배달 하면 배달 비 얼마 에요
# A: 2000원 이요
#
#
# Q: 아 혹시 제 가 국물 이 먹고 싶어서 라면 을 먹고 싶은데 돈까스 나 뭐 쫄면 먹다가 싸 주실 수 있나요
# A: 예 예 는 육류
#
#
# Q: 그럼 제 가 매장 으로 갈 경우 에 포장 으로 한 몇 분 정도 걸리죠
# A: 일곱 이 요
#
#
# processing epoch: 31...
# Epoch 1/10
# 79/79 [==============================] - 16s 207ms/step - loss: 0.7011 - acc: 0.8728
# Epoch 2/10
# 79/79 [==============================] - 16s 207ms/step - loss: 0.6906 - acc: 0.8739
# Epoch 3/10
# 79/79 [==============================] - 16s 205ms/step - loss: 0.6807 - acc: 0.8751
# Epoch 4/10
# 79/79 [==============================] - 16s 205ms/step - loss: 0.6702 - acc: 0.8766
# Epoch 5/10
# 79/79 [==============================] - 16s 205ms/step - loss: 0.6602 - acc: 0.8778
# Epoch 6/10
# 79/79 [==============================] - 17s 211ms/step - loss: 0.6514 - acc: 0.8789
# Epoch 7/10
# 79/79 [==============================] - 16s 204ms/step - loss: 0.6416 - acc: 0.8806
# Epoch 8/10
# 79/79 [==============================] - 16s 204ms/step - loss: 0.6329 - acc: 0.8818
# Epoch 9/10
# 79/79 [==============================] - 16s 203ms/step - loss: 0.6244 - acc: 0.8829
# Epoch 10/10
# 79/79 [==============================] - 16s 204ms/step - loss: 0.6157 - acc: 0.8840
# Q: 사 천 탕수육 이 들어간 세트 는 없나요
# A: 네 는 에 포함
#
#
# Q: 삼선짬뽕 배달 은 몇 시 까지 해 요
# A: 10시 요
#
#
# Q: 짜장면 한강 으로 배달 주문 하면 추가 비용 이 얼마 죠
# A: 짜장면 비는 은 추가 무료
#
#
# processing epoch: 41...
# Epoch 1/10
# 79/79 [==============================] - 16s 205ms/step - loss: 0.6068 - acc: 0.8850
# Epoch 2/10
# 79/79 [==============================] - 16s 205ms/step - loss: 0.5992 - acc: 0.8863
# Epoch 3/10
# 79/79 [==============================] - 16s 207ms/step - loss: 0.5905 - acc: 0.8872
# Epoch 4/10
# 79/79 [==============================] - 16s 205ms/step - loss: 0.5838 - acc: 0.8883
# Epoch 5/10
# 79/79 [==============================] - 16s 207ms/step - loss: 0.5761 - acc: 0.8900
# Epoch 6/10
# 79/79 [==============================] - 17s 211ms/step - loss: 0.5681 - acc: 0.8904
# Epoch 7/10
# 79/79 [==============================] - 16s 207ms/step - loss: 0.5616 - acc: 0.8918
# Epoch 8/10
# 79/79 [==============================] - 16s 203ms/step - loss: 0.5543 - acc: 0.8925
# Epoch 9/10
# 79/79 [==============================] - 16s 205ms/step - loss: 0.5471 - acc: 0.8938
# Epoch 10/10
# 79/79 [==============================] - 18s 223ms/step - loss: 0.5391 - acc: 0.8948
# Q: 영수증 주세요 카드 영수증 챙겨주세요
# A: 네 알겠습니다 영수증 발급 네
#
#
# Q: 레스토랑 에서 먼 주소지 일수록 배달 비 가 더 비싼가요
# A: 네 배달 곳 은 배달 비 가 붙습니다 붙습니다 붙습니다
#
#
# Q: 피자 치즈 변경 하고 싶은데 가능한 치즈 종류 좀 알려주시겠어요
# A: 신 도 으로 는 없습니다 와 치즈 입니다
#
#
# processing epoch: 51...
# Epoch 1/10
# 79/79 [==============================] - 16s 204ms/step - loss: 0.5325 - acc: 0.8961
# Epoch 2/10
# 79/79 [==============================] - 16s 204ms/step - loss: 0.5253 - acc: 0.8968
# Epoch 3/10
# 79/79 [==============================] - 16s 204ms/step - loss: 0.5174 - acc: 0.8983
# Epoch 4/10
# 79/79 [==============================] - 17s 213ms/step - loss: 0.5124 - acc: 0.8989
# Epoch 5/10
# 79/79 [==============================] - 16s 205ms/step - loss: 0.5058 - acc: 0.9000
# Epoch 6/10
# 79/79 [==============================] - 17s 214ms/step - loss: 0.4993 - acc: 0.9011
# Epoch 7/10
# 79/79 [==============================] - 16s 206ms/step - loss: 0.4931 - acc: 0.9016
# Epoch 8/10
# 79/79 [==============================] - 16s 205ms/step - loss: 0.4867 - acc: 0.9033
# Epoch 9/10
# 79/79 [==============================] - 17s 211ms/step - loss: 0.4804 - acc: 0.9039
# Epoch 10/10
# 79/79 [==============================] - 16s 205ms/step - loss: 0.4734 - acc: 0.9050
# Q: 떡볶이 시키면 배달 비 얼마나 지불 해야하죠
# A: 배달 비는 2000원 2000원 지불 4000원 까지 내야 하시면 야합니다
#
#
# Q: 참치 김밥 3 개주실래요
# A: 네 포장 됩니다
#
#
# Q: 맥주 랑 소주 뭐 가 있나요
# A: 네가지 는 기본 있구요 있구요
#
#
# processing epoch: 61...
# Epoch 1/10
# 79/79 [==============================] - 16s 208ms/step - loss: 0.4686 - acc: 0.9057
# Epoch 2/10
# 79/79 [==============================] - 16s 206ms/step - loss: 0.4630 - acc: 0.9066
# Epoch 3/10
# 79/79 [==============================] - 17s 209ms/step - loss: 0.4564 - acc: 0.9082
# Epoch 4/10
# 79/79 [==============================] - 16s 205ms/step - loss: 0.4511 - acc: 0.9085
# Epoch 5/10
# 79/79 [==============================] - 16s 206ms/step - loss: 0.4446 - acc: 0.9097
# Epoch 6/10
# 79/79 [==============================] - 17s 209ms/step - loss: 0.4391 - acc: 0.9106
# Epoch 7/10
# 79/79 [==============================] - 16s 204ms/step - loss: 0.4324 - acc: 0.9120
# Epoch 8/10
# 79/79 [==============================] - 16s 206ms/step - loss: 0.4275 - acc: 0.9122
# Epoch 9/10
# 79/79 [==============================] - 16s 204ms/step - loss: 0.4217 - acc: 0.9137
# Epoch 10/10
# 79/79 [==============================] - 16s 206ms/step - loss: 0.4161 - acc: 0.9145
# Q: 고수 도 들어가나요 런치세트 에서 선택 가능한 파스타 메뉴 는 뭐 가 있나요
# A: 네 그렇게 가격 따로 주문 하셔야 합니다 때 이 안
#
#
# Q: 김밥 에서 햄 만 빼줄 수 있어요
# A: 네 맞아요 드릴게요 수 있습니다
#
#
# Q: 세트 이 구성은 어떻게 돼요
# A: 탕수육 과 짜 순 살 치킨 콜라 오 백 미리 요
#
#
# processing epoch: 71...
# Epoch 1/10
# 79/79 [==============================] - 16s 206ms/step - loss: 0.4110 - acc: 0.9152
# Epoch 2/10
# 79/79 [==============================] - 16s 204ms/step - loss: 0.4048 - acc: 0.9164
# Epoch 3/10
# 79/79 [==============================] - 16s 204ms/step - loss: 0.4017 - acc: 0.9173
# Epoch 4/10
# 79/79 [==============================] - 16s 204ms/step - loss: 0.3954 - acc: 0.9182
# Epoch 5/10
# 79/79 [==============================] - 16s 202ms/step - loss: 0.3912 - acc: 0.9185
# Epoch 6/10
# 79/79 [==============================] - 16s 207ms/step - loss: 0.3851 - acc: 0.9207
# Epoch 7/10
# 79/79 [==============================] - 16s 203ms/step - loss: 0.3807 - acc: 0.9209
# Epoch 8/10
# 79/79 [==============================] - 16s 204ms/step - loss: 0.3759 - acc: 0.9215
# Epoch 9/10
# 79/79 [==============================] - 17s 216ms/step - loss: 0.3707 - acc: 0.9227
# Epoch 10/10
# 79/79 [==============================] - 16s 206ms/step - loss: 0.3661 - acc: 0.9234
# Q: 아 그래서 양 이 많은가요
# A: 네 분 이 나와요 에 보시
#
#
# Q: 볶 짬면은 볶음밥 과 짬뽕 구성 인가요
# A: 네 맞습니다
#
#
# Q: 마늘 이랑 고추 상추 도 나오죠
# A: 네 나갑니다
#
#
# processing epoch: 81...
# Epoch 1/10
# 79/79 [==============================] - 17s 209ms/step - loss: 0.3613 - acc: 0.9243
# Epoch 2/10
# 79/79 [==============================] - 16s 203ms/step - loss: 0.3559 - acc: 0.9256
# Epoch 3/10
# 79/79 [==============================] - 16s 206ms/step - loss: 0.3545 - acc: 0.9252
# Epoch 4/10
# 79/79 [==============================] - 16s 203ms/step - loss: 0.3479 - acc: 0.9267
# Epoch 5/10
# 79/79 [==============================] - 16s 205ms/step - loss: 0.3443 - acc: 0.9276
# Epoch 6/10
# 79/79 [==============================] - 16s 209ms/step - loss: 0.3385 - acc: 0.9289
# Epoch 7/10
# 79/79 [==============================] - 16s 202ms/step - loss: 0.3350 - acc: 0.9298
# Epoch 8/10
# 79/79 [==============================] - 16s 205ms/step - loss: 0.3319 - acc: 0.9297
# Epoch 9/10
# 79/79 [==============================] - 16s 204ms/step - loss: 0.3276 - acc: 0.9309
# Epoch 10/10
# 79/79 [==============================] - 16s 205ms/step - loss: 0.3229 - acc: 0.9317
# Q: 지금 배달 되나요
# A: 네 됩니다
#
#
# Q: 족발 좀 포장 해 가려고요
# A: 네
#
#
# Q: 그럼 배달 앱 도 안 하세요
# A: 배달 의 은 거리
#
#
# processing epoch: 91...
# Epoch 1/10
# 79/79 [==============================] - 16s 206ms/step - loss: 0.3189 - acc: 0.9327
# Epoch 2/10
# 79/79 [==============================] - 16s 203ms/step - loss: 0.3147 - acc: 0.9335
# Epoch 3/10
# 79/79 [==============================] - 16s 205ms/step - loss: 0.3110 - acc: 0.9342
# Epoch 4/10
# 79/79 [==============================] - 16s 205ms/step - loss: 0.3064 - acc: 0.9350
# Epoch 5/10
# 79/79 [==============================] - 17s 210ms/step - loss: 0.3029 - acc: 0.9359
# Epoch 6/10
# 79/79 [==============================] - 16s 204ms/step - loss: 0.2998 - acc: 0.9363
# Epoch 7/10
# 79/79 [==============================] - 16s 204ms/step - loss: 0.2955 - acc: 0.9373
# Epoch 8/10
# 79/79 [==============================] - 16s 205ms/step - loss: 0.2925 - acc: 0.9382
# Epoch 9/10
# 79/79 [==============================] - 16s 203ms/step - loss: 0.2874 - acc: 0.9384
# Epoch 10/10
# 79/79 [==============================] - 16s 204ms/step - loss: 0.2841 - acc: 0.9396
# Q: 짜장면 시키니까 이번 에 배달 비 가 많이 나오는데 이유 가 뭔가 요
# A: 거리 가 저번 에 따라 멀어지셔서 그렇습니다
#
#
# Q: 치킨 우면동 까지 배달 하시면 배달 비 얼마 에요
# A: 배달 비는 2000원 입니다
#
#
# Q: 택배 는 안 돼나요
# A: 다 는 끝났죠 내일 발송 하면 토요일 날 받으시니깐 요
#
#
# processing epoch: 101...
# Epoch 1/10
# 79/79 [==============================] - 16s 204ms/step - loss: 0.2808 - acc: 0.9404
# Epoch 2/10
# 79/79 [==============================] - 16s 201ms/step - loss: 0.2763 - acc: 0.9412
# Epoch 3/10
# 79/79 [==============================] - 16s 204ms/step - loss: 0.2723 - acc: 0.9418
# Epoch 4/10
# 79/79 [==============================] - 16s 206ms/step - loss: 0.2693 - acc: 0.9427
# Epoch 5/10
# 79/79 [==============================] - 16s 207ms/step - loss: 0.2662 - acc: 0.9438
# Epoch 6/10
# 79/79 [==============================] - 16s 205ms/step - loss: 0.2621 - acc: 0.9442
# Epoch 7/10
# 79/79 [==============================] - 16s 204ms/step - loss: 0.2583 - acc: 0.9450
# Epoch 8/10
# 79/79 [==============================] - 16s 205ms/step - loss: 0.2554 - acc: 0.9454
# Epoch 9/10
# 79/79 [==============================] - 16s 204ms/step - loss: 0.2519 - acc: 0.9462
# Epoch 10/10
# 79/79 [==============================] - 16s 207ms/step - loss: 0.2482 - acc: 0.9468
# Q: 이 거 알밥 정식 에는 뭐 가 나와요
# A: 돈가스 이랑 미니 돈카츠 랑 미니 냉 모밀 이 요
#
#
# Q: 중화 치킨 샐러드 배달 하 면 배달 비 얼마 에요
# A: 2000원 이요
#
#
# Q: 배달 은 요
# A: 배달 되요
#
#
# processing epoch: 111...
# Epoch 1/10
# 79/79 [==============================] - 16s 205ms/step - loss: 0.2473 - acc: 0.9474
# Epoch 2/10
# 79/79 [==============================] - 16s 202ms/step - loss: 0.2424 - acc: 0.9482
# Epoch 3/10
# 79/79 [==============================] - 16s 205ms/step - loss: 0.2391 - acc: 0.9490
# Epoch 4/10
# 79/79 [==============================] - 16s 205ms/step - loss: 0.2369 - acc: 0.9501
# Epoch 5/10
# 79/79 [==============================] - 16s 205ms/step - loss: 0.2330 - acc: 0.9503
# Epoch 6/10
# 79/79 [==============================] - 16s 207ms/step - loss: 0.2293 - acc: 0.9511
# Epoch 7/10
# 79/79 [==============================] - 16s 207ms/step - loss: 0.2269 - acc: 0.9515
# Epoch 8/10
# 79/79 [==============================] - 16s 203ms/step - loss: 0.2239 - acc: 0.9524
# Epoch 9/10
# 79/79 [==============================] - 16s 206ms/step - loss: 0.2209 - acc: 0.9533
# Epoch 10/10
# 79/79 [==============================] - 16s 203ms/step - loss: 0.2179 - acc: 0.9535
# Q: 최초 주문 금액 12000원 맞아요
# A: 네 맞아요
#
#
# Q: 저기 믹스 주먹밥 은 다른 두 가지 가 섞여 있는 건가 요
# A: 예 참치 랑 김치 랑
#
#
# Q: 모듬 초밥 은 몇개 에요
# A: 열 개 나옵니다
#
#
# processing epoch: 121...
# Epoch 1/10
# 79/79 [==============================] - 16s 203ms/step - loss: 0.2161 - acc: 0.9540
# Epoch 2/10
# 79/79 [==============================] - 16s 204ms/step - loss: 0.2130 - acc: 0.9547
# Epoch 3/10
# 79/79 [==============================] - 16s 204ms/step - loss: 0.2102 - acc: 0.9552
# Epoch 4/10
# 79/79 [==============================] - 16s 206ms/step - loss: 0.2071 - acc: 0.9559
# Epoch 5/10
# 79/79 [==============================] - 16s 206ms/step - loss: 0.2048 - acc: 0.9565
# Epoch 6/10
# 79/79 [==============================] - 16s 207ms/step - loss: 0.2023 - acc: 0.9570
# Epoch 7/10
# 79/79 [==============================] - 16s 202ms/step - loss: 0.1987 - acc: 0.9581
# Epoch 8/10
# 79/79 [==============================] - 16s 207ms/step - loss: 0.1962 - acc: 0.9585
# Epoch 9/10
# 79/79 [==============================] - 16s 206ms/step - loss: 0.1946 - acc: 0.9587
# Epoch 10/10
# 79/79 [==============================] - 16s 204ms/step - loss: 0.1908 - acc: 0.9597
# Q: 포장 가능할까 요
# A: 네 가능합니다
#
#
# Q: 술잔 은 다 드릴 까요
# A: 네 다 잔 은 다주 시구 요
#
#
# Q: 몇 개 나 나오나요
# A: 열 개 나옵니다
#
#
# processing epoch: 131...
# Epoch 1/10
# 79/79 [==============================] - 16s 205ms/step - loss: 0.1894 - acc: 0.9601
# Epoch 2/10
# 79/79 [==============================] - 16s 206ms/step - loss: 0.1860 - acc: 0.9609
# Epoch 3/10
# 79/79 [==============================] - 16s 205ms/step - loss: 0.1836 - acc: 0.9616
# Epoch 4/10
# 79/79 [==============================] - 16s 204ms/step - loss: 0.1819 - acc: 0.9621
# Epoch 5/10
# 79/79 [==============================] - 16s 206ms/step - loss: 0.1798 - acc: 0.9621
# Epoch 6/10
# 79/79 [==============================] - 16s 203ms/step - loss: 0.1779 - acc: 0.9625
# Epoch 7/10
# 79/79 [==============================] - 16s 205ms/step - loss: 0.1737 - acc: 0.9641
# Epoch 8/10
# 79/79 [==============================] - 16s 207ms/step - loss: 0.1715 - acc: 0.9648
# Epoch 9/10
# 79/79 [==============================] - 16s 206ms/step - loss: 0.1700 - acc: 0.9646
# Epoch 10/10
# 79/79 [==============================] - 16s 204ms/step - loss: 0.1672 - acc: 0.9654
# Q: 군 만두 있는 걸 로 먹고 싶은데 세트 2 번 시키면 되는 건지 궁금합니다
# A: 네 세트 2 번 시키시면 군 만두 도 포함 되어 있네요
#
#
# Q: 굽 네 스윗 볼케이노 통 다리 배달 하면 배달 비 얼마 에요
# A: 2000원 이요
#
#
# Q: 만원 에 몇 마리 주세요
# A: 4 마리 들어가요
#
#
# processing epoch: 141...
# Epoch 1/10
# 79/79 [==============================] - 16s 203ms/step - loss: 0.1657 - acc: 0.9654
# Epoch 2/10
# 79/79 [==============================] - 16s 206ms/step - loss: 0.1633 - acc: 0.9658
# Epoch 3/10
# 79/79 [==============================] - 16s 204ms/step - loss: 0.1610 - acc: 0.9664
# Epoch 4/10
# 79/79 [==============================] - 16s 209ms/step - loss: 0.1595 - acc: 0.9669
# Epoch 5/10
# 79/79 [==============================] - 16s 207ms/step - loss: 0.1576 - acc: 0.9673
# Epoch 6/10
# 79/79 [==============================] - 16s 204ms/step - loss: 0.1550 - acc: 0.9677
# Epoch 7/10
# 79/79 [==============================] - 16s 207ms/step - loss: 0.1538 - acc: 0.9682
# Epoch 8/10
# 79/79 [==============================] - 16s 205ms/step - loss: 0.1503 - acc: 0.9694
# Epoch 9/10
# 79/79 [==============================] - 16s 203ms/step - loss: 0.1484 - acc: 0.9690
# Epoch 10/10
# 79/79 [==============================] - 16s 207ms/step - loss: 0.1465 - acc: 0.9695
# Q: 마 요 쉬 림프 는 큰거는 몇 개 나오는거에요
# A: 다섯 개요
#
#
# Q: 떡볶이 2 인분 시킬 건데 배달 료 가 있는 거 예요
# A: 따로 배달 료 는 없습니다
#
#
# Q: 애플 어니언 치킨 배달 하면 배달 비 얼마 에요
# A: 2000원 이요

# %%
# 모델 저장
encoder_model.save('/content/drive/MyDrive/Colab Notebooks/ssac/nlp/model/encoder_model.h5')
decoder_model.save('/content/drive/MyDrive/Colab Notebooks/ssac/nlp/model/decoder_model.h5')

with open('/content/drive/MyDrive/Colab Notebooks/ssac/nlp/tokenizer/seq2seq_tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
